# %% [markdown]
# ## Is it correct to fit a simple SIR to our model's equations?

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import xlrd
from scipy import stats
import matplotlib.cm as cm
import matplotlib.colors as mcolors

# %% [markdown]
# Simple SIR model:

# %%
#Initial conditions and t range
t = np.arange(0,40, 0.3)
k0=[1 - 0.01, 0.01, 0] #normalized population

#Differential equation
eta = 0.5
gamma = 1/14
def f(k,t):
    S = k[0]
    I = k[1]
    R = k[2]
    dSdt = -1*eta*I*S
    dIdt = eta*I*S - gamma*I
    dRdt = gamma*I
    return [dSdt, dIdt, dRdt]


#Solve
k_s = odeint(f,k0,t)

#Plotting
plt.plot(t,k_s[:,0],'r--', linewidth=2.0)
plt.plot(t,k_s[:,1],'b-', linewidth=2.0)
plt.plot(t,k_s[:,2],'g-', linewidth=2.0)

#print(k[20, 0])
plt.title("SIR Model")    #'$\u03B2 =$ {}, $\gamma =$ {}'.format(eta, gamma))
plt.xlabel("$t$")
plt.ylabel("$[S, I, R]$")
plt.legend(["$S$","$I$", "$R$"])

# plt.savefig('sir.png', dpi = 1200)

# %% [markdown]
# Divied population with varios $\beta$ differentiation:

# %%
gamma = 1/14
delta = 1
betam = 7/14

def equations(k,t):
    betat, betal = betam * (1 - 0.5 * delta), betam * (1 + 0.5 * delta) #symmetry

    ST, IT, RT = k[0], k[1], k[2]
    SM, IM, RM = k[3], k[4], k[5]
    SL, IL, RL = k[6], k[7], k[8]
    I = IT + IM + IL
    S = ST + SM + SL
    #top
    dSTdt = -1*betat*I*ST
    dITdt = betat*I*ST - gamma*IT
    dRTdt = gamma*IT
    #medium
    dSMdt = -1*betam*I*SM
    dIMdt = betam*I*SM - gamma*IM
    dRMdt = gamma*IM
    #low
    dSLdt = -1*betal*I*SL
    dILdt = betal*I*SL - gamma*IL
    dRLdt = gamma*IL
    
    return [dSTdt, dITdt, dRTdt, dSMdt, dIMdt, dRMdt, dSLdt, dILdt, dRLdt]

# %%
#Initial conditions and t range
t  =  np.arange(0,130, 0.001)
k0 = [0.33, 0.01, 0, 0.33, 0, 0, 0.33, 0, 0]

#Solve
k = odeint(equations,k0,t)

Itot = k[:, 1]+k[:, 4]+k[:, 7]

# %%
def find_range(cases):
    begin = 0 
    end = np.size(cases)-1
    for i in range(1, end):
        if cases[i] != 0 and begin == 0:
            begin = i
        if begin != 0:
            if i <= 3: shift = 1
            else: shift = i - 3

            if cases[i] < np.average(cases[shift:i]):
                end = i
                break
    end = int(end/5)
    begin = int(end/20)
    return begin, end

# %%
plt.plot(t, np.log(Itot))

plt.ylabel('log(I)')
plt.xlabel('t')
plt.title('Infected people in time')
# Out:
# Text(0.5, 1.0, 'Infected people in time')

# %%
find_range(Itot)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\numpy\lib\function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Users\ASUS\anaconda3\lib\site-packages\numpy\core\_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# (156, 3131)

# %%
def fit_equation(cases): 
    begin, end = find_range(cases)
    betaSgamma = np.polyfit(t[begin:end], np.log(list(cases[begin:end])), 1)[0] #should be corrected in the originial code
    return betaSgamma

# %%
begin, end = find_range(Itot)
a, b = np.polyfit(t[begin:end], np.log(list(Itot[begin:end])), 1)

plt.plot(t[begin:end], np.log(list(Itot[begin:end])), '--', label = 'data')
plt.plot(t[begin:end], a * t[begin:end] + b, label = 'fit')

plt.legend()
plt.ylabel('log(I)')
plt.xlabel('t')
plt.title('Infected people in the fit range')
# Out:
# Text(0.5, 1.0, 'Infected people in the fit range')

# %%
fit_equation(Itot)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\numpy\lib\function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Users\ASUS\anaconda3\lib\site-packages\numpy\core\_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 0.41626814169036686

# %%
def find_beta(cases):
    population = 1
    return (fit_equation(cases) + gamma)/population

# %%
find_beta(Itot)
# Out:
# 0.48769671311893825

# %%
eta = find_beta(Itot)
gamma = 1/14

def f(k,t):
    S = k[0]
    I = k[1]
    R = k[2]
    dSdt = -1*eta*I*S
    dIdt = eta*I*S - gamma*I
    dRdt = gamma*I
    return [dSdt, dIdt, dRdt]

k0 = [1-0.01, 0.01, 0]
k_s = odeint(f,k0,t)

# %%
plt.plot(t, Itot, label = '3 classes model')
plt.plot(t, k_s[:, 1], label = 'fit')

plt.xlabel('t')
plt.ylabel('I')
plt.legend()

# %%
#linear plot in range of the fitted data
#Error 
#define least square and look for the best range for other parameters

error = sum((Itot - k_s[:, 1])**2)

error
# Out:
# 13.279474328463293

# %%
gamma = 1/14
# t  =  np.arange(0,100, 0.05)
def find_error(betam, delta):
    def equations(k,t):
        betat, betal = betam * (1 - 0.5 * delta), betam * (1 + 0.5 * delta) #symmetry

        ST, IT, RT = k[0], k[1], k[2]
        SM, IM, RM = k[3], k[4], k[5]
        SL, IL, RL = k[6], k[7], k[8]
        I = IT + IM + IL
        S = ST + SM + SL
        #top
        dSTdt = -1*betat*I*ST
        dITdt = betat*I*ST - gamma*IT
        dRTdt = gamma*IT
        #medium
        dSMdt = -1*betam*I*SM
        dIMdt = betam*I*SM - gamma*IM
        dRMdt = gamma*IM
        #low
        dSLdt = -1*betal*I*SL
        dILdt = betal*I*SL - gamma*IL
        dRLdt = gamma*IL

        return [dSTdt, dITdt, dRTdt, dSMdt, dIMdt, dRMdt, dSLdt, dILdt, dRLdt]
    #Initial conditions and t range
    k0 = [0.33, 0.01, 0, 0.33, 0, 0, 0.33, 0, 0]
    #Solve
    k = odeint(equations,k0,t)
    Itot = k[:, 1]+k[:, 4]+k[:, 7]
    
    beta = find_beta(Itot)

    def SIR(k,t):
        S = k[0]
        I = k[1]
        R = k[2]
        dSdt = -1*beta*I*S
        dIdt = beta*I*S - gamma*I
        dRdt = gamma*I
        return [dSdt, dIdt, dRdt]

    k0 = [1-0.01, 0.01, 0]
    k_s = odeint(SIR,k0,t)
    
    return sum((Itot - k_s[:, 1])**2)

# %%
find_error(0.1, 0)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\numpy\lib\function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Users\ASUS\anaconda3\lib\site-packages\numpy\core\_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#
#  12.527263594913443,
#  11.309180585549829,
#  10.213074831440437,
#  9.270820553628036,
#  8.464426501435995,
#  7.767679972966518,
#  7.166112830503241,
#  6.643064594459311,
#  6.183462929575316,
#  5.783453062543232,
#  5.4309457264168515,
#  5.116377511070602,
#  4.84112345670129,
#  4.59528974948612,
#  4.375946653672112,
#  4.180696779588127,
#  4.005011701535719,
#  3.842879455313988,
#  1.1469972386295153,
#  12.402585704049732,
#  16.12646368685015,
#  16.005957491674586,
#  14.801630384515304,
#  13.454251003376363,
#  12.220147946745652,
#  11.14221059849298,
#  10.205195716997562,
#  9.38796662692125,
#  8.671469516476568,
#  8.040765336249017,
#  7.484298230593621,
#  6.991089962870478,
#  6.553873783842131,
#  6.165131933457042,
#  5.818828505509629,
#  5.508396442206239,
#  5.230627285954349,
#  4.980530000057496,
#  4.754041500454849,
#  4.549500353522009]

# %%
plt.contourf(betam_range, delta_range, Error, 100, cmap = cm.jet)

plt.ylabel('$\delta$')
plt.xlabel('$\u03B2$')

normalize = mcolors.Normalize(vmin=np.min(error), vmax=np.max(error))
colormap = cm.jet

scalarmappaple = cm.ScalarMappable(norm=normalize, cmap=colormap)
scalarmappaple.set_array(error)
plt.subplots_adjust(bottom=0.1, wspace=1, hspace=None)
cbar_ax = None 
cbar = plt.colorbar(scalarmappaple, orientation="vertical", pad=0.1, cax=cbar_ax) 
cbar.set_label('$error$')

# %%
# %%time

delta_range = np.arange(0, 1, 0.05)
betam_range = np.arange(0.1, 1.2, 0.05)

def find_beta_eff(betam, delta):
    def equations(k,t):
        betat, betal = betam * (1 - 0.5 * delta), betam * (1 + 0.5 * delta) #symmetry

        ST, IT, RT = k[0], k[1], k[2]
        SM, IM, RM = k[3], k[4], k[5]
        SL, IL, RL = k[6], k[7], k[8]
        I = IT + IM + IL
        S = ST + SM + SL
        #top
        dSTdt = -1*betat*I*ST
        dITdt = betat*I*ST - gamma*IT
        dRTdt = gamma*IT
        #medium
        dSMdt = -1*betam*I*SM
        dIMdt = betam*I*SM - gamma*IM
        dRMdt = gamma*IM
        #low
        dSLdt = -1*betal*I*SL
        dILdt = betal*I*SL - gamma*IL
        dRLdt = gamma*IL

        return [dSTdt, dITdt, dRTdt, dSMdt, dIMdt, dRMdt, dSLdt, dILdt, dRLdt]
    #Initial conditions and t range
    k0 = [0.33, 0.01, 0, 0.33, 0, 0, 0.33, 0, 0]
    #Solve
    k = odeint(equations,k0,t)
    Itot = k[:, 1]+k[:, 4]+k[:, 7]
    
    beta = find_beta(Itot)
    return beta




beta_eff = []
for delta in delta_range:
    for betam in betam_range:
        beta_eff.append(find_beta_eff(betam, delta))

beta_eff
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\numpy\lib\function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Users\ASUS\anaconda3\lib\site-packages\numpy\core\_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#
#  0.6361504369453763,
#  0.6841494736359629,
#  0.7340684564875274,
#  0.7820899825355415,
#  0.8326140188875972,
#  0.8807633424405905,
#  0.9287776620091034,
#  0.9803026016168489,
#  1.028571970833479,
#  1.0767392800601847,
#  1.124798894530743,
#  0.09853417212043926,
#  0.14732052934162077,
#  0.19562807639055024,
#  0.24438526248983297,
#  0.2935620933379607,
#  0.3422952498280676,
#  0.391262101056978,
#  0.440571832214504,
#  0.48947479083048795,
#  0.5385641615006822,
#  0.5866296956493061,
#  0.6360562012122135,
#  0.6840362645313128,
#  0.7339603501403051,
#  0.7819631865277887,
#  0.832499940259088,
#  0.8806321441712169,
#  0.9286276922219037,
#  0.9801779708784975,
#  1.0284317064732564,
#  1.0765821115638803,
#  1.124623527079309,
#  0.09852787582571008,
#  0.14730465004174287,
#  0.19559632374851058,
#  0.24434359766907618,
#  0.2935160695851581,
#  0.3422390131769325,
#  0.3911987253290361,
#  0.44050582037257935,
#  0.48940079355168364,
#  0.5384847300018339,
#  0.586531201543941,
#  0.6359565897279005,
#  0.6839165973168501,
#  0.733846076946383,
#  0.7818291566098208,
#  0.832379353490128,
#  0.880493462660738,
#  0.9284691667994047,
#  0.980046229254448,
#  1.0282834387350148,
#  1.0764159784152476,
#  1.1244381539113404]

# %%
beta_eff = np.array(beta_eff)
beta_eff = beta_eff.reshape(len(delta_range), len(betam_range))

plt.contourf(betam_range, delta_range, beta_eff, 100, cmap = cm.jet)

plt.ylabel('$\delta$')
plt.xlabel('$\u03B2$')

normalize = mcolors.Normalize(vmin=np.min(beta_eff), vmax=np.max(beta_eff))
colormap = cm.jet

scalarmappaple = cm.ScalarMappable(norm=normalize, cmap=colormap)
scalarmappaple.set_array(beta_eff)
plt.subplots_adjust(bottom=0.1, wspace=1, hspace=None)
cbar_ax = None 
cbar = plt.colorbar(scalarmappaple, orientation="vertical", pad=0.1, cax=cbar_ax) 
cbar.set_label('$beta_eff$')

# %%
betam_range
# Out:
# array([0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 , 0.55, 0.6 ,
#        0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  , 1.05, 1.1 , 1.15])

# %%
def find_delta_beta(betam, delta):
    def equations(k,t):
        betat, betal = betam * (1 - 0.5 * delta), betam * (1 + 0.5 * delta) #symmetry

        ST, IT, RT = k[0], k[1], k[2]
        SM, IM, RM = k[3], k[4], k[5]
        SL, IL, RL = k[6], k[7], k[8]
        I = IT + IM + IL
        S = ST + SM + SL
        #top
        dSTdt = -1*betat*I*ST
        dITdt = betat*I*ST - gamma*IT
        dRTdt = gamma*IT
        #medium
        dSMdt = -1*betam*I*SM
        dIMdt = betam*I*SM - gamma*IM
        dRMdt = gamma*IM
        #low
        dSLdt = -1*betal*I*SL
        dILdt = betal*I*SL - gamma*IL
        dRLdt = gamma*IL

        return [dSTdt, dITdt, dRTdt, dSMdt, dIMdt, dRMdt, dSLdt, dILdt, dRLdt]
    #Initial conditions and t range
    k0 = [0.33, 0.01, 0, 0.33, 0, 0, 0.33, 0, 0]
    #Solve
    k = odeint(equations,k0,t)
normalize = mcolors.Normalize(vmin=np.min(delta_beta), vmax=np.max(delta_beta))
colormap = cm.jet

scalarmappaple = cm.ScalarMappable(norm=normalize, cmap=colormap)
scalarmappaple.set_array(delta_beta)
plt.subplots_adjust(bottom=0.1, wspace=1, hspace=None)
cbar_ax = None 
cbar = plt.colorbar(scalarmappaple, orientation="vertical", pad=0.1, cax=cbar_ax) 
cbar.set_label('$\Delta beta /beta $')

# %%
# %%time

delta_range = np.arange(0, 1, 0.05)
betam_range = np.arange(0.1, 1.2, 0.05)




beta_eff = []
delta = 1.9
for betam in betam_range:
    beta_eff.append(find_beta_eff(betam, delta))

plt.plot(betam_range, beta_eff, label = 'fit')
plt.ylabel("beta_eff")
plt.xlabel("betam")
plt.plot([0, 1], [0, 1], '--')
plt.legend()
# Out:
# Wall time: 153 ms
# C:\Users\ASUS\anaconda3\lib\site-packages\numpy\lib\function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Users\ASUS\anaconda3\lib\site-packages\numpy\core\_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
# %%time

delta_range = np.arange(0, 0.3, 0.05)
betam_range = np.arange(0.5, 3, 0.1)/14

error = []
for delta in delta_range:
    for betam in betam_range:
        error.append(find_error(betam, delta))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-101-34a546fe215a> in find_error(betam, delta)
#      30     Itot = k[:, 1]+k[:, 4]+k[:, 7]
#      31
# ---> 32     beta = find_beta(Itot)
#      33
#      34     def SIR(k,t):
#
# <ipython-input-93-77d1fb274553> in find_beta(cases)
#       1 def find_beta(cases):
#       2     population = 1
# ----> 3     return (fit_equation(cases) + gamma)/population
#
# <ipython-input-90-db6b979f059f> in fit_equation(cases)
#       1 def fit_equation(cases):
#       2     begin, end = find_range(cases)
# ----> 3     betaSgamma = np.polyfit(t[begin:end], np.log(list(cases[begin:end])), 1)[0] #should be corrected in the originial code
#       4     return betaSgamma
#
# <__array_function__ internals> in polyfit(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     628         raise TypeError("expected 1D vector for x")
#     629     if x.size == 0:
# --> 630         raise TypeError("expected non-empty vector for x")
#     631     if y.ndim < 1 or y.ndim > 2:
#     632         raise TypeError("expected 1D or 2D array for y")
#
# TypeError: expected non-empty vector for x

# %%
error = np.array(error)
Error = error.reshape(len(delta_range), len(betam_range))

plt.contourf(betam_range, delta_range, Error, 100, cmap = cm.jet)


plt.ylabel('$\delta$')
plt.xlabel('$\u03B2$')


normalize = mcolors.Normalize(vmin=np.min(error), vmax=np.max(error))
colormap = cm.jet

scalarmappaple = cm.ScalarMappable(norm=normalize, cmap=colormap)
scalarmappaple.set_array(error)
plt.subplots_adjust(bottom=0.1, wspace=1, hspace=None)
cbar_ax = None 
cbar = plt.colorbar(scalarmappaple, orientation="vertical", pad=0.1, cax=cbar_ax) 
cbar.set_label('$error$')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-75d697518ea6> in <module>
#      14 scalarmappaple = cm.ScalarMappable(norm=normalize, cmap=colormap)
#      15 scalarmappaple.set_array(error)
# ---> 16 fig.subplots_adjust(bottom=0.1, wspace=1, hspace=None)
#      17 cbar_ax = None
#      18 cbar = plt.colorbar(scalarmappaple, orientation="vertical", pad=0.1, cax=cbar_ax)
#
# NameError: name 'fig' is not defined

# %%
gamma = 1/14

def diff_plot(betam, delta):
    def equations(k,t):
        betat, betal = betam * (1 - 0.5 * delta), betam * (1 + 0.5 * delta) #symmetry

        ST, IT, RT = k[0], k[1], k[2]
        SM, IM, RM = k[3], k[4], k[5]
        SL, IL, RL = k[6], k[7], k[8]
        I = IT + IM + IL
        S = ST + SM + SL
        #top
        dSTdt = -1*betat*I*ST
        dITdt = betat*I*ST - gamma*IT
        dRTdt = gamma*IT
        #medium
        dSMdt = -1*betam*I*SM
        dIMdt = betam*I*SM - gamma*IM
        dRMdt = gamma*IM
        #low
        dSLdt = -1*betal*I*SL
        dILdt = betal*I*SL - gamma*IL
        dRLdt = gamma*IL

        return [dSTdt, dITdt, dRTdt, dSMdt, dIMdt, dRMdt, dSLdt, dILdt, dRLdt]
    #Initial conditions
    k0 = [0.33, 0.01, 0, 0.33, 0, 0, 0.33, 0, 0]
    #Solve
    k = odeint(equations,k0,t)
    Itot = k[:, 1]+k[:, 4]+k[:, 7]
    
    beta = find_beta(Itot)

    def SIR(k,t):
        S = k[0]
        I = k[1]
        R = k[2]
        dSdt = -1*beta*I*S
        dIdt = beta*I*S - gamma*I
        dRdt = gamma*I
        return [dSdt, dIdt, dRdt]

    k0 = [1-0.01, 0.01, 0]
    k_s = odeint(SIR,k0,t)
    
    plt.plot(t, Itot, label = '3 classes model')
    plt.plot(t, k_s[:, 1], label = 'fit')

    plt.xlabel('t')
    plt.ylabel('I')
    plt.legend()

# %%
delta = 0
betam = 0.2
t  =  np.arange(0,100, 0.001)
diff_plot(betam, delta)

# %%
# %%time

delta_range = np.arange(0, 0.1, 0.01)
betam_range = np.arange(0.1, 1.2, 0.05)

error = []
for delta in delta_range:
    for betam in betam_range:
        error.append(find_error(betam, delta))

error
# Out:
# Wall time: 2min
# [3.756067816408807,
#  8.998683534715259,
#  10.87135424192814,
#  11.269466575730549,
#  11.122343547576111,
#  10.753120326688395,
#  10.305503729656815,
#  9.844707256932583,
#  9.399589520360683,
#  8.979412935683857,
#  8.594663662527406,
#  8.239484024544133,
#  7.909966242109889,
#  7.612316425565825,
#  7.338105007392644,
#  7.083821357553481,
#  6.8552549800901845,
#  6.639388132494325,
#  6.433681356986206,
#  6.249252284442583,
#  6.075989980273714,
#  5.918212691565911,
#  3.7556282991850396,
#  8.997692383469882,
#  10.870035211229046,
#  11.267914903032885,
#  11.120649857652618,
#  10.751356066236745,
#  10.303796946744125,
#  9.842955036684945,
#  9.39787867279858,
#  8.97775287938196,
#  8.593061746664214,
#  8.237941702708877,
#  7.908482294607005,
#  7.610889416894827,
#  7.336731979494296,
#  7.0824965693045705,
#  6.853985677479331,
#  6.638160587654785,
#  6.432496449550371,
#  6.248110004811891,
#  6.082354227209714,
#  5.917138976083814,
#  3.7543097312825258,
#  8.994718565581838,
#  10.864288428427757,
#  11.263262537856995,
#  11.115571586139195,
#  10.746076252339094,
#  10.298484008062784,
#  9.837697625369971,
#  9.392745494637254,
#  8.972776812371656,
#  8.588260766284609,
#  8.23331819694626,
#  7.006383765701331,
#  6.7810295175517314,
#  6.568245203238402,
#  6.365451472773248,
#  6.183721442105557,
#  6.01299850407023,
#  5.857582875859754,
#  3.717825028877225,
#  8.916445268063564,
#  10.764123492489468,
#  11.14495473584461,
#  10.98639787482363,
#  10.615411950189875,
#  10.167190007827966,
#  9.70831953248855,
#  9.266763185753833,
#  8.85633739545145,
#  8.471358483221097,
#  8.121221450152364,
#  7.80259859420725,
#  7.5038097961752905,
#  7.23418666972355,
#  6.984210693363841,
#  6.759657841025601,
#  6.547631998396575,
#  6.352661883149084,
#  6.164491408992523,
#  6.001825557028083,
#  5.839558289892108]

# %%
error = np.array(error)
Error = error.reshape(len(delta_range), len(betam_range))

plt.contourf(betam_range, delta_range, Error, 100, cmap = cm.jet)


plt.ylabel('$\delta$')
plt.xlabel('$\u03B2$')


normalize = mcolors.Normalize(vmin=np.min(error), vmax=np.max(error))
colormap = cm.jet

scalarmappaple = cm.ScalarMappable(norm=normalize, cmap=colormap)
scalarmappaple.set_array(error)
plt.subplots_adjust(bottom=0.1, wspace=1, hspace=None)
cbar_ax = None 
cbar = plt.colorbar(scalarmappaple, orientation="vertical", pad=0.1, cax=cbar_ax) 
cbar.set_label('$error$')

# %% [markdown]
# Check if the fit is not exact.
# Fitting the curve to a simple SIR data.

# %%
#Initial conditions and t range
t = np.arange(0,40, 0.3)
k0=[1 - 0.01, 0.01, 0] #normalized population

#Differential equation
eta = 0.5
gamma = 1/14
def f(k,t):
    S = k[0]
    I = k[1]
    R = k[2]
    dSdt = -1*eta*I*S
    dIdt = eta*I*S - gamma*I
    dRdt = gamma*I
    return [dSdt, dIdt, dRdt]


#Solve
k_s = odeint(f,k0,t)

#Plotting
plt.plot(t,k_s[:,0],'r--', linewidth=2.0)
plt.plot(t,k_s[:,1],'b-', linewidth=2.0)
plt.plot(t,k_s[:,2],'g-', linewidth=2.0)

#print(k[20, 0])
plt.title("SIR Model")    #'$\u03B2 =$ {}, $\gamma =$ {}'.format(eta, gamma))
plt.xlabel("$t$")
plt.ylabel("$[S, I, R]$")
plt.legend(["$S$","$I$", "$R$"])

# plt.savefig('sir.png', dpi = 1200)

# %%
beta = find_beta(k_s[:, 1])

def f(k,t):
    S = k[0]
    I = k[1]
    R = k[2]
    dSdt = -1*beta*I*S
    dIdt = beta*I*S - gamma*I
    dRdt = gamma*I
    return [dSdt, dIdt, dRdt]


#Solve
k_ss = odeint(f,k0,t)

#Plotting
plt.plot(t,k_ss[:,1],'b--', linewidth=2.0)
plt.plot(t,k_s[:,1],'b-', linewidth=2.0)
# plt.plot(t,k_s[:,2],'g-', linewidth=2.0)

#print(k[20, 0])
plt.title("Simple SIR Fit")    #'$\u03B2 =$ {}, $\gamma =$ {}'.format(eta, gamma))
plt.xlabel("$t$")
plt.ylabel("$I$")
plt.legend(["$Fit$","$Data$"])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\numpy\lib\function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Users\ASUS\anaconda3\lib\site-packages\numpy\core\_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
beta
# Out:
# 0.49012245449152814
