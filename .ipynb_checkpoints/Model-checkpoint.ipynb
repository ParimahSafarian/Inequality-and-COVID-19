# %% [markdown]
# ## A hand shake to the equations

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import xlrd
from scipy import stats
import matplotlib.cm as cm
import matplotlib.colors as mcolors

# %% [markdown]
# Simple SIR model:

# %%
#Differential equation
def f(k,t):
    eta = 0.0015
    gamma = 0.2
    S = k[0]
    I = k[1]
    R = k[2]
    dSdt = -1*eta*I*S
    dIdt = eta*I*S - gamma*I
    dRdt = gamma*I
    return [dSdt, dIdt, dRdt]

#Initial conditions and t range
t = np.arange(0,30, 0.3)
k0=[995,5, 0]

#Solve
k = odeint(f,k0,t)
k = k / sum(k0)

#Plotting
plt.plot(t,k[:,0],'r--', linewidth=2.0)
plt.plot(t,k[:,1],'b-', linewidth=2.0)
plt.plot(t,k[:,2],'g-', linewidth=2.0)

#print(k[20, 0])
plt.title("SIR Model")    #'$\u03B2 =$ {}, $\gamma =$ {}'.format(eta, gamma))
plt.xlabel("$t$")
plt.ylabel("$[S, I, R]$")
plt.legend(["$S$","$I$", "$R$"])

plt.savefig('sir.png', dpi = 1200)

# %%
x = t
y = k[:, 1]

fig, ax = plt.subplots()
ax.plot(x,y, 'b-')

ax.plot(t,k[:,0],'r--', linewidth=2.0)
ax.plot(t,k[:,2],'g-', linewidth=2.0)

def annot_max(x,y, ax=None):
    xmax = x[np.argmax(y)]
    ymax = y.max()
    text= "peak time={:.0f}, maximum infected portion={:.2f}".format(xmax, ymax)
    if not ax:
        ax=plt.gca()
    bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
    arrowprops=dict(arrowstyle="->",connectionstyle="angle,angleA=0,angleB=60")
    kw = dict(xycoords='data',textcoords="axes fraction",
              arrowprops=arrowprops, bbox=bbox_props, ha="right", va="top")
    ax.annotate(text, xy=(xmax, ymax), xytext=(0.94,0.96), **kw)

annot_max(x,y)
ax.set_ylim([0, 1])
ax.set_xlim([0, 33])
xmax = x[np.argmax(y)]
ymax = y.max()
print(ymax)
ax.axvline(x=xmax, ymin=0, ymax=ymax/1, ls = '--')
ax.axhline(y=ymax, xmin=0, xmax=xmax/33, ls = '--')


ax.set_xlabel("$t$")
ax.set_ylabel("$I$")

plt.text(23, 0.4, 'SIR equations:\n $\dot{S}=-\u03B2 SI$\n $\dot{I}=\u03B2 SI -\gamma I$\n $\dot{R}=\gamma I$', fontweight="bold")

plt.show()

fig.savefig('measures.png', dpi = 1200)
# Out:
# 0.5985697756153805

# %% [markdown]
# Divied population with varios $\beta$ differentiation:

# %%
gamma = 1/14
delta = 1
betam = 7/14

def equations(k,t):
    betat, betal = betam * (1 - 0.5 * delta), betam * (1 + 0.5 * delta) #symmetry

    ST, IT, RT = k[0], k[1], k[2]
    SM, IM, RM = k[3], k[4], k[5]
    SL, IL, RL = k[6], k[7], k[8]
    I = IT + IM + IL
    S = ST + SM + SL
    #top
    dSTdt = -1*betat*I*ST
    dITdt = betat*I*ST - gamma*IT
    dRTdt = gamma*IT
    #medium
    dSMdt = -1*betam*I*SM
    dIMdt = betam*I*SM - gamma*IM
    dRMdt = gamma*IM
    #low
    dSLdt = -1*betal*I*SL
    dILdt = betal*I*SL - gamma*IL
    dRLdt = gamma*IL
    
    return [dSTdt, dITdt, dRTdt, dSMdt, dIMdt, dRMdt, dSLdt, dILdt, dRLdt]

# %%
#Initial conditions and t range
t  =  np.arange(0,55, 0.01)

k0 = [0.33, 0.01, 0, 0.33, 0, 0, 0.33, 0, 0]

# %%
#Solve
k = odeint(equations,k0,t)

# %%
plt.plot(t, k[:,1]+k[:,4]+k[:,7])

# %%
print(np.sum(k[0, :]))
print(np.shape(k))

plt.plot(t, np.sum(k, axis = 1))
# Out:
# 1.0
# (5500, 9)

# %%
pop = k[:, 1::3].sum(1)
Itot = k[:,1]+k[:,4]+k[:,7]
pop == Itot
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
Imax = []
delta_range = np.arange(0, 1.1, 0.1)
t_p = []

normalize = mcolors.Normalize(vmin=delta_range.min(), vmax=delta_range.max())
colormap = cm.viridis

for delta in delta_range:
    k0 = [0.33, 0.01, 0, 0.33, 0, 0, 0.33, 0, 0]
    k = odeint(equations,k0,t)
    Itot = k[:, 1::3].sum(1)
    Imax.append(max(Itot))
    t_p.append(np.where(Itot == max(Itot))[0][0])
    plt.plot(t, Itot, label = f'{round(delta, 1)}', color = colormap(normalize(delta)))

# plt.legend(title = '$\delta$', loc = 'upper left')
scalarmappaple = cm.ScalarMappable(norm=normalize, cmap=colormap)
scalarmappaple.set_array(delta_range)
plt.colorbar(scalarmappaple)

plt.ylabel("$ifected portion$")
plt.xlabel("$time$")

# plt.savefig('delta.png', dpi = 1200)
# Out:
# Text(0.5, 0, '$time$')

# %%
plt.plot(Imax, delta_range, '.')

plt.ylabel('$\delta$')
plt.xlabel('$Maximum Infected Portion$')

# plt.savefig('MIPdelta.png', dpi = 1200)
# Out:
# Text(0.5, 0, '$Maximum Infected Portion$')

# %%
plt.plot(t_p, delta_range, '.')

plt.ylabel('$\delta$')
plt.xlabel('$t_{peak}$')

# plt.savefig('tpdelta.png', dpi = 1200)
# Out:
# Text(0.5, 0, '$t_{peak}$')

# %%
plt.figure(figsize=(12, 6))
ax1 = plt.subplot(2,2,1)
ax2 = plt.subplot(2,2,3)
ax3 = plt.subplot(1,2,2)
axes = [ax3, ax1, ax2]

Imax = []
delta_range = np.arange(0, 1.1, 0.1)
t_p = []

normalize = mcolors.Normalize(vmin=delta_range.min(), vmax=delta_range.max())
colormap = cm.viridis

for delta in delta_range:
    k0 = [0.33, 0.01, 0, 0.33, 0, 0, 0.33, 0, 0]
    k = odeint(equations,k0,t)
    Itot = k[:, 1::3].sum(1)
    Imax.append(max(Itot))
    t_p.append(np.where(Itot == max(Itot))[0][0])
    plt.plot(t, Itot, label = f'{round(delta, 1)}', color = colormap(normalize(delta)))

# plt.legend(title = '$\delta$', loc = 'upper left')
scalarmappaple = cm.ScalarMappable(norm=normalize, cmap=colormap)
scalarmappaple.set_array(delta_range)
plt.colorbar(scalarmappaple)


# ax3.legend(title = '$\delta$', loc = 'upper left')
ax3.set_ylabel("Ifected Portion")
ax3.set_xlabel("time")


ax1.plot(t_p, delta_range, c = 'green')
ax1.set_ylabel('$\delta$')
ax1.set_xlabel('peak time')

ax2.plot(Imax, delta_range, c = 'purple')
ax2.set_ylabel('$\delta$')
ax2.set_xlabel('Maximum Infected Portion')


plt.savefig('delta.png', dpi = 1200)

# %%
plt.bar(['poor', 'medium', 'rich'], [1/3, 1/3, 1/3], color = 'indigo')
plt.ylim(0, 0.5)
plt.title('Popluation Distribution', fontsize = 16)
plt.tick_params(axis='both', which='major', labelsize=14)
plt.savefig('dist1.png', dpi = 1200)

# %% [markdown]
# for $\Delta N$:
# \begin{align}
# NT = NM \epsilon\\
# NL = NM (4\epsilon)\\
# NM + NT + NL = 1\\
# NM = \frac{1}{1+5\epsilon}
# \end{align}

# %%
delta = 1.5
eps_range = np.arange(0, 1.1, 0.1)

Imax = []
t_p = []

t  =  np.arange(0,55, 0.01)

from random import randint
colors = []

for i in range(len(eps_range)):
    colors.append('#%06X' % randint(0, 0xFFFFFF))
    
for epsilon in eps_range:
    M = 1/ (1 + 5 * epsilon)
    T, L = M * epsilon, 4 * M * epsilon
    plt.bar(['poor', 'medium', 'rich'], [L, M, T], alpha = 0.2, label = f'{round(epsilon, 1)}')#,
#             hatch = '-', edgecolor = colors[np.where(eps_range == epsilon)[0][0]])
    k0 = [T, 0, 0, M, 0.01, 0, L, 0, 0]
    k = odeint(equations,k0,t)
    Itot = k[:, 1::3].sum(1)
    Imax.append(max(Itot))
    t_p.append(np.where(Itot == max(Itot))[0][0])


plt.title("Population Distribution")
plt.legend(title = '$\epsilon$')

plt.savefig('dist2.png', dpi = 1200)

# %%
delta = 1.5
eps_range = np.arange(0, 1.1, 0.1)

Imax = []
t_p = []

t  =  np.arange(0,55, 0.01)

normalize = mcolors.Normalize(vmin=eps_range.min(), vmax=eps_range.max())
colormap = cm.jet



width = 1
for epsilon in eps_range:
    M = 1/ (1 + 5 * epsilon)
    T, L = M * epsilon, 4 * M * epsilon
    plt.bar(['poor', 'medium', 'rich'], [L, M, T], fill=False, label = f'{round(epsilon, 1)}',
             edgecolor = colormap(normalize(epsilon)), width = width)
    width = width - 0.08
    k0 = [T, 0, 0, M, 0.01, 0, L, 0, 0]
    k = odeint(equations,k0,t)
    Itot = k[:, 1::3].sum(1)
    Imax.append(max(Itot))
    t_p.append(np.where(Itot == max(Itot))[0][0])


plt.title("Population Distribution", fontsize = 16)
plt.tick_params(axis='both', which='major', labelsize=14)
# scalarmappaple = cm.ScalarMappable(norm=normalize, cmap=colormap)
# scalarmappaple.set_array(delta_range)
# plt.colorbar(scalarmappaple)


plt.savefig('dist2.png', dpi = 1200)

# %%
delta = 1.5
eps_range = np.arange(0, 1.1, 0.1)
Imax = []
t_p = []

normalize = mcolors.Normalize(vmin=eps_range.min(), vmax=eps_range.max())
colormap = cm.jet

t  =  np.arange(0,55, 0.01)


for epsilon in eps_range:
    M = 1/ (1 + 5 * epsilon)
    T, L = M * epsilon, 4 * M * epsilon
    k0 = [T, 0, 0, M, 0.01, 0, L, 0, 0]
    k = odeint(equations,k0,t)
    Itot = k[:, 1::3].sum(1)
    Imax.append(max(Itot))
    t_p.append(np.where(Itot == max(Itot))[0][0])
    plt.plot(t, Itot, label = f'{round(epsilon, 1)}', color = colormap(normalize(epsilon)))
    
# plt.legend(title = '$\epsilon$')
scalarmappaple = cm.ScalarMappable(norm=normalize, cmap=colormap)
scalarmappaple.set_array(delta_range)
plt.colorbar(scalarmappaple)

plt.ylabel("$I$")
plt.xlabel("$t$")

# plt.savefig('pop.png', dpi = 1200)
# Out:
# Text(0.5, 0, '$t$')

# %%
plt.plot(t_p, eps_range, '.')
plt.xlabel('$t_{peak}$')
plt.ylabel('$\epsilon$')
plt.title('inequlity parameter versus peak time')
plt.savefig('epstpeak.png', dpi = 1200)

# %%
plt.plot(Imax, eps_range, '.')
plt.xlabel('$I_{max}$')
plt.ylabel('$\epsilon$')
plt.savefig('epsImax.png', dpi = 1200)

# %%
plt.figure(figsize=(12, 6))
ax1 = plt.subplot(2,2,1)
ax2 = plt.subplot(2,2,3)
ax3 = plt.subplot(1,2,2)
axes = [ax3, ax1, ax2]

delta = 1.5
eps_range = np.arange(0, 1.1, 0.1)
Imax = []
t_p = []

normalize = mcolors.Normalize(vmin=eps_range.min(), vmax=eps_range.max())
colormap = cm.jet

t  =  np.arange(0,55, 0.01)


for epsilon in eps_range:
    M = 1/ (1 + 5 * epsilon)
    T, L = M * epsilon, 4 * M * epsilon
    k0 = [T, 0, 0, M, 0.01, 0, L, 0, 0]
    k = odeint(equations,k0,t)
    Itot = k[:, 1::3].sum(1)
    Imax.append(max(Itot))
    t_p.append(np.where(Itot == max(Itot))[0][0])
    plt.plot(t, Itot, label = f'{round(epsilon, 1)}', color = colormap(normalize(epsilon)))
    
# plt.legend(title = '$\epsilon$')
scalarmappaple = cm.ScalarMappable(norm=normalize, cmap=colormap)
scalarmappaple.set_array(delta_range)
plt.colorbar(scalarmappaple)

ax3.set_ylabel("Ifected Portion")
ax3.set_xlabel("time")


ax1.plot(t_p, eps_range, c = 'r')
ax1.set_ylabel('$\epsilon$')
ax1.set_xlabel('peak time')

ax2.plot(Imax, eps_range, c = 'b')
ax2.set_ylabel('$\epsilon$')
ax2.set_xlabel('Maximum Infected Portion')


plt.savefig('pop.png', dpi = 1200)

# %% [markdown]
# ## Gini Coefficient
# Gini Coefficient calculation for $\epsilon$:

# %%
epsilon = 0.2
AL, AM, AT = 1, 5, 10 #Assets of each group


M = 1/ (1 + 5 * epsilon)
T, L = M * epsilon, 4 * M * epsilon


points = np.zeros((4, 2))
points[1] = [L, (AL*L) / (AL*L + AM*M + AT*T)]
points[2] = [L + M, (AL*L + AM*M) / (AL*L + AM*M + AT*T)]
points[3] = [1, 1]

plt.fill_between(points[:, 0], points[:, 1], points[:, 0], fc = 'orange', alpha = 0.7)
plt.fill_between(points[:, 0], [0, 0, 0, 0], points[:, 1], fc = 'lightskyblue', alpha = 0.7)

plt.plot(points[:, 0], points[:, 1], c = 'darkorange')

plt.plot([0, 1], [0, 1], c = 'darkorange')

angle = 0
plt.text(0.35, 0.3, 'Area A', fontweight="bold", rotation = angle)
plt.text(0.8, 0.2, 'Area B', fontweight="bold", rotation = angle)
plt.text(0.1, 0.8, 'Gini Coefficient: $\dfrac{A}{A+B}$', fontweight="bold", rotation = angle)
plt.axis('scaled')

plt.ylabel('Cumulative Percent of Income')
plt.xlabel('Cumulative Percent of Population')

plt.savefig('ginidef.png', dpi = 1200)

# %%
from shapely.geometry import Polygon

AL, AM, AT = 1, 3, 9 #Assets of each group 
gini = []
eps_range = np.arange(0, 1.1, 0.1)

for epsilon in eps_range:
    M = 1/ (1 + 5 * epsilon)
    T, L = M * epsilon, 4 * M * epsilon


    points = np.zeros((4, 2))
    points[1] = [L, (AL*L) / (AL*L + AM*M + AT*T)]
    points[2] = [L + M, (AL*L + AM*M) / (AL*L + AM*M + AT*T)]
    points[3] = [1, 1]

    plt.plot(points[:, 0], points[:, 1], color = colormap(normalize(epsilon)))

    pgon = Polygon(points)
    gini.append((pgon.area * 2))
    
plt.ylabel('Cumulative Percent of Income')
plt.xlabel('Cumulative Percent of Population')
angle = 45
plt.text(0.25, 0.3, 'Perfect Equality Line', fontweight="normal", rotation = angle)
plt.axis('scaled')   

plt.savefig('simugini.png', dpi = 1200)    


# plt.figure()
# plt.plot(eps_range, gini, c = 'b')
# plt.ylabel("Gini Coefficient")
# plt.xlabel("$\epsilon$")
# scalarmappaple = cm.ScalarMappable(norm=normalize, cmap=colormap)
# scalarmappaple.set_array(delta_range)
# plt.colorbar(scalarmappaple)

# plt.savefig('simueps.png', dpi = 1200)

# %%
plt.figure(figsize=(12, 6))
ax1 = plt.subplot(2,2,1)
ax2 = plt.subplot(2,2,3)
ax3 = plt.subplot(1,2,2)
axes = [ax3, ax1, ax2]

ax3.plot(eps_range, gini, c = 'b')
ax3.set_ylabel("Gini Coefficient")
ax3.set_xlabel("$\epsilon$")
scalarmappaple = cm.ScalarMappable(norm=normalize, cmap=colormap)
scalarmappaple.set_array(delta_range)
plt.colorbar(scalarmappaple)


ax1.plot(t_p, gini, c = 'r')
ax1.set_xlabel('Peak Time')
ax1.set_ylabel('Simulated Gini Coefficient')

ax2.plot(Imax, gini, '.', c = 'b')
ax2.set_xlabel('Maximum Infected Portion$')
ax2.set_ylabel('Simulated Gini Coefficient')


plt.savefig('simueps.png', dpi = 1200)

# %%
plt.plot(Imax, gini, '.')
# plt.ylabel('$t_{peak}$')
# plt.xlabel('Gini')
